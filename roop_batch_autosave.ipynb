# %% [markdown]
# ## roop换脸
# 此文件的作用是使用roop插件进行批量换脸，只需要定义源文件夹，目标文件夹，脸部参考图片，即可进行批量换脸，换脸后的图片会保存在目标文件夹中。

# %%
import json
import random
import uuid
import urllib.request
import urllib.parse
from urllib.error import URLError
import io
import os
import time
from PIL.PngImagePlugin import PngInfo
from PIL import Image
import hashlib

# %% [markdown]
# ## import json file

# %%
promptJson = 'roop_api.json'

with open(promptJson) as f:
    prompt = json.load(f)

print(str(prompt))
# Out:
# {'12': {'inputs': {'image': '020_0.png', 'choose file to upload': 'image'}, 'class_type': 'LoadImage'}, '34': {'inputs': {'swap_model': 'inswapper_128.onnx', 'faces_index': '0', 'reference_faces_index': '0', 'face_order': 'left to right', 'reverse_order': False, 'reference_order': 'left to right', 'reverse_reference_order': False, 'console_logging_level': 0, 'image': ['12', 0], 'reference_image': ['35', 0]}, 'class_type': 'RoopImproved'}, '35': {'inputs': {'image': '828bbd3b93befac87c8ae2a61dd552f0.jpeg', 'choose file to upload': 'image'}, 'class_type': 'LoadImage'}, '41': {'inputs': {'facedetection': 'retinaface_resnet50', 'codeformer_fidelity': 0.5, 'facerestore_model': ['42', 0], 'image': ['34', 0]}, 'class_type': 'FaceRestoreCFWithModel'}, '42': {'inputs': {'model_name': 'GFPGANv1.4.pth'}, 'class_type': 'FaceRestoreModelLoader'}, '43': {'inputs': {'images': ['41', 0]}, 'class_type': 'PreviewImage'}}

# %%
server_address = "127.0.0.1:8188"
client_id = str(uuid.uuid4())

# %%
def changeImageSize(width, height):
    # 最小的宽高为 896
    limited = 896
    minSize = min(width, height)

    # 缩放宽高，使得最窄的边等于limited
    if minSize > limited:
        scale = minSize / limited
        widthScale = int(width / scale)
        heightScale = int(height / scale)
    else:
        scale = limited / minSize
        widthScale = int(width * scale)
        heightScale = int(height * scale)

    # 将两个值都除以64，然后取整,也就是说边长必须是64的倍数
    widthScale = int(widthScale/64) * 64
    heightScale = int(heightScale/64) * 64

    return widthScale, heightScale

def checkImageExsit(imageDir, imageName):
    for file in os.listdir(imageDir):
        if file.startswith(imageName):
            return True
    return False


def queue_prompt(prompt):
    while True:
        try:
            p = {"prompt": prompt, "client_id": client_id}
            data = json.dumps(p).encode('utf-8')
            req = urllib.request.Request("http://{}/prompt".format(server_address), data=data)
            return json.loads(urllib.request.urlopen(req, timeout=5).read())
        except URLError:
            print("连接超时，正在重试...")

def get_history(prompt_id):
    with urllib.request.urlopen("http://{}/history/{}".format(server_address, prompt_id)) as response:
        return json.loads(response.read())

def get_image(filename, subfolder, folder_type):
    data = {"filename": filename, "subfolder": subfolder, "type": folder_type}
    url_values = urllib.parse.urlencode(data)
    with urllib.request.urlopen("http://{}/view?{}".format(server_address, url_values)) as response:
        return response.read()

def handle_whitespace(string: str):
    return string.strip().replace("\n", " ").replace("\r", " ").replace("\t", " ")

def parse_name(ckpt_name):
    path = ckpt_name
    filename = path.split("/")[-1]
    filename = filename.split(".")[:-1]
    filename = ".".join(filename)
    return filename


def calculate_sha256(file_path):
    sha256_hash = hashlib.sha256()

    with open(file_path, "rb") as f:
        # Read the file in chunks to avoid loading the entire file into memory
        for byte_block in iter(lambda: f.read(4096), b""):
            sha256_hash.update(byte_block)

    return sha256_hash.hexdigest()

def get_images(ws, prompt):
    prompt_id = queue_prompt(prompt)['prompt_id']
    output_images = {}
    while True:
        out = ws.recv()
        if isinstance(out, str):
            message = json.loads(out)
            if message['type'] == 'executing':
                data = message['data']
                if data['node'] is None and data['prompt_id'] == prompt_id:
                    break #Execution is done
        else:
            continue #previews are binary data

    history = get_history(prompt_id)[prompt_id]
    for o in history['outputs']:
        for node_id in history['outputs']:
            node_output = history['outputs'][node_id]
            if 'images' in node_output:
                images_output = []
                for image in node_output['images']:
                    image_data = get_image(image['filename'], image['subfolder'], image['type'])
                    images_output.append(image_data)
                output_images[node_id] = images_output

    return output_images
    
def saveImages(result, imageDir,imageName,comment,previewImage=0): 
    metadata = PngInfo()
    metadata.add_text("parameters", comment)  
    k = 0 
    for node_id in result:    
        if k < previewImage:
            k += 1
            continue    
        for image_data in result[node_id]:            
            image = Image.open(io.BytesIO(image_data))
            imagePath = imageDir + "/" + imageName + f"_{k}" + ".png"
            image.save(imagePath,pnginfo=metadata) 
            k += 1

# %%
# 子文件夹
subDir = "BoA"

# 原图文件夹
originalDir = f"E:/roop-face/source-video/temp/test-video"
# 设置图片保存路径
imageDir = f"E:/roop-face/source-video/temp/test-video-output"
# 如果文件夹不存在，创建文件夹
if not os.path.exists(imageDir):
    os.mkdir(imageDir)
    
# 这里是要替换的人脸图片
faceReferenceImagePath = "c:/Users/BigHippo78/Documents/WeChat Files/highmore78/FileStorage/File/2023-10/奶茶多多/奶茶多多/face.png"

# %%
import websocket

ws = websocket.WebSocket()
ws.connect("ws://{}/ws?clientId={}".format(server_address, client_id))

# 这些参数是乱写的
positive = ''
negative = ''
steps = 35
sampler_name = 'dpmpp_2m_sde'
scheduler = 'karras'
cfg = 7
seed = random.randint(0, 1000000)

count = 0

batch_size = 1
# 遍历原图文件夹里所有的图片
for originalImag in os.listdir(originalDir):
        # if count > 55:
        #     break
        # 如果不是jpg或png文件，跳过
        if not (originalImag.endswith(".jpg") or originalImag.endswith(".png") or originalImag.endswith(".jpeg")):
            continue
        
        originalImagePath = originalDir + "/" + originalImag
        # 如果文件名包含_H或者_B，跳过
        if originalImag.find("_H") != -1 or originalImag.find("_B") != -1:
            print(f"{originalImag}包含_H或者_B,判定为mask文件，跳过")
        
        # 读取原图片名字，去掉后缀.png
        originalImagName = originalImag.split(".")[0]
        # 检测目标文件夹里是否已经存在该图片，如果存在，跳过
        if checkImageExsit(imageDir, originalImagName):
            print(f"{originalImagName}已经存在，跳过")
            continue 
        
        # roop只需要两个参数，就是原图片和脸部参考图片
        prompt['35']['inputs']['image'] = faceReferenceImagePath
        prompt['12']['inputs']['image'] = originalImagePath       
        
        comment = ''    
        
        # 连接api，生成并保存图片
        start_time = time.time()        
        images = get_images(ws, prompt)   
        saveImages(images, imageDir, originalImagName, comment=comment,previewImage=0)     
        end_time = time.time()
        print(f"耗时{end_time-start_time}秒")
        count += 1
        print(f"已经生成{count}张图片")
# Out:
# 0001已经存在，跳过
# 0002已经存在，跳过
# 0003已经存在，跳过
# 0004已经存在，跳过
# 0005已经存在，跳过
# 0006已经存在，跳过
# 0007已经存在，跳过
# 0008已经存在，跳过
# 0009已经存在，跳过
# 0010已经存在，跳过
# 0011已经存在，跳过
# 0012已经存在，跳过
# 0013已经存在，跳过
# 0014已经存在，跳过
# 0015已经存在，跳过
# 0016已经存在，跳过
# 0017已经存在，跳过
# 0018已经存在，跳过
# 0019已经存在，跳过
# 0020已经存在，跳过
# 0021已经存在，跳过
# 0022已经存在，跳过
# 0023已经存在，跳过
# 0024已经存在，跳过
# 0025已经存在，跳过
# 0026已经存在，跳过
# 0027已经存在，跳过
# 0028已经存在，跳过
# 0029已经存在，跳过
# 0030已经存在，跳过
# 0031已经存在，跳过
# 0032已经存在，跳过
# 0033已经存在，跳过
# 0034已经存在，跳过
# 0035已经存在，跳过
# 0036已经存在，跳过
# 0037已经存在，跳过
# 0038已经存在，跳过
# 0039已经存在，跳过
# 0040已经存在，跳过
# 0041已经存在，跳过
# 0042已经存在，跳过
# 0043已经存在，跳过
# 0044已经存在，跳过
# 0045已经存在，跳过
# 0046已经存在，跳过
# 0047已经存在，跳过
# 0048已经存在，跳过
# 0049已经存在，跳过
# 0050已经存在，跳过
# 0051已经存在，跳过
# 0052已经存在，跳过
# 0053已经存在，跳过
# 0054已经存在，跳过
# 0055已经存在，跳过
# 0056已经存在，跳过
# 0057已经存在，跳过
# 0058已经存在，跳过
# 0059已经存在，跳过
# 0060已经存在，跳过
# 0061已经存在，跳过
# 0062已经存在，跳过
# 0063已经存在，跳过
# 0064已经存在，跳过
# 0065已经存在，跳过
# 0066已经存在，跳过
# 0067已经存在，跳过
# 0068已经存在，跳过
# 0069已经存在，跳过
# 0070已经存在，跳过
# 0071已经存在，跳过
# 0072已经存在，跳过
# 0073已经存在，跳过
# 0074已经存在，跳过
# 0075已经存在，跳过
# 0076已经存在，跳过
# 0077已经存在，跳过
# 0078已经存在，跳过
# 0079已经存在，跳过
# 0080已经存在，跳过
# 0081已经存在，跳过
# 0082已经存在，跳过
# 0083已经存在，跳过
# 0084已经存在，跳过
# 0085已经存在，跳过
# 0086已经存在，跳过
# 0087已经存在，跳过
# 0088已经存在，跳过
# 0089已经存在，跳过
# 0090已经存在，跳过
# 0091已经存在，跳过
# 0092已经存在，跳过
# 0093已经存在，跳过
# 0094已经存在，跳过
# 0095已经存在，跳过
# 0096已经存在，跳过
# 0097已经存在，跳过
# 0098已经存在，跳过
# 0099已经存在，跳过
# 0100已经存在，跳过
# 0101已经存在，跳过
# 0102已经存在，跳过
# 0103已经存在，跳过
# 0104已经存在，跳过
# 0105已经存在，跳过
# 0106已经存在，跳过
# 0107已经存在，跳过
# 耗时4.784407377243042秒
# 已经生成279张图片
# 耗时4.833025217056274秒
# 已经生成280张图片
# 耗时4.765659809112549秒
# 已经生成281张图片
# 耗时4.831043243408203秒
# 已经生成282张图片
# 耗时4.792252779006958秒
# 已经生成283张图片
# 耗时4.738407135009766秒
# 已经生成284张图片
# 耗时4.8568315505981445秒
# 已经生成285张图片
# 耗时4.783652067184448秒
# 已经生成286张图片
# 耗时4.823598384857178秒
# 已经生成287张图片
# 耗时4.965724945068359秒
# 已经生成288张图片
# 耗时5.030137300491333秒
# 已经生成289张图片
# 耗时4.7724549770355225秒
# 已经生成290张图片
# 耗时4.888139009475708秒
# 已经生成291张图片
# 耗时4.700642824172974秒
# 已经生成292张图片
# 耗时4.837594032287598秒
# 已经生成293张图片
# 耗时4.755582332611084秒
# 已经生成294张图片
# 耗时4.830889701843262秒
# 已经生成295张图片
# 耗时4.7478251457214355秒
# 已经生成296张图片
# 耗时4.668319463729858秒
# 已经生成297张图片
# 耗时4.770931720733643秒
# 已经生成298张图片
# 耗时4.808422088623047秒
# 已经生成299张图片
# 耗时4.8091514110565186秒
# 已经生成300张图片
# 耗时4.796878337860107秒
# 已经生成301张图片
# 耗时4.996161222457886秒
# 已经生成302张图片
# 耗时4.772761106491089秒
# 已经生成303张图片
# 耗时5.002143144607544秒
# 已经生成304张图片
# 耗时4.773573637008667秒
# 已经生成305张图片
# 耗时5.386675834655762秒
# 已经生成306张图片
# 耗时5.635624885559082秒
# 已经生成307张图片
# 耗时4.819371700286865秒
# 已经生成308张图片
# 耗时5.022770404815674秒
# 已经生成309张图片
# 耗时4.998100519180298秒
# 已经生成310张图片
# 耗时4.9685142040252686秒
# 已经生成311张图片
# 耗时5.645164728164673秒
# 已经生成312张图片
# 耗时4.996570825576782秒
# 已经生成313张图片
# 耗时5.0008704662323秒
# 已经生成314张图片
# 耗时5.1775290966033936秒
# 已经生成315张图片
# 耗时4.941127777099609秒
# 已经生成316张图片
# 耗时5.253098964691162秒
# 已经生成317张图片
# 耗时5.166482925415039秒
# 已经生成318张图片
# 耗时5.199654579162598秒
# 已经生成319张图片
# 耗时5.22973370552063秒
# 已经生成320张图片
# 耗时5.082841634750366秒
# 已经生成321张图片
# 耗时5.312736749649048秒
# 已经生成322张图片
# 耗时5.20073390007019秒
# 已经生成323张图片
# 耗时5.578553915023804秒
# 已经生成324张图片
# 耗时5.2110915184021秒
# 已经生成325张图片
# 耗时5.791287422180176秒
# 已经生成326张图片
# 耗时5.002913236618042秒
# 已经生成327张图片
# 耗时5.53368878364563秒
# 已经生成328张图片
# 耗时5.0519256591796875秒
# 已经生成329张图片
# 耗时5.397953271865845秒
# 已经生成330张图片
# 耗时5.607527494430542秒
# 已经生成331张图片
# 耗时5.12459659576416秒
# 已经生成332张图片
# 耗时5.479646682739258秒
# 已经生成333张图片
# 耗时5.385952949523926秒
# 已经生成334张图片
# 耗时5.400052547454834秒
# 已经生成335张图片
# 耗时4.988478899002075秒
# 已经生成336张图片
# 已经生成394张图片
# 耗时4.78768253326416秒
# 已经生成395张图片
# 耗时4.80069375038147秒
# 已经生成396张图片
# 耗时5.210490942001343秒
# 已经生成397张图片
# 耗时5.694237232208252秒
# 已经生成398张图片
# 耗时5.297748804092407秒
# 已经生成399张图片
# 耗时5.384429216384888秒
# 已经生成400张图片
# 耗时5.125440359115601秒
# 已经生成401张图片
# 耗时6.06950831413269秒
# 已经生成402张图片
# 耗时5.181745529174805秒
# 已经生成403张图片
# 耗时4.802025556564331秒
# 已经生成404张图片
# 耗时4.79987096786499秒
# 已经生成405张图片
# 耗时4.612679481506348秒
# 已经生成406张图片
# 耗时4.787751197814941秒
# 已经生成407张图片
# 耗时5.090445041656494秒
# 已经生成408张图片
# 耗时4.8903093338012695秒
# 已经生成409张图片
# 耗时5.275677919387817秒
# 已经生成410张图片
# 耗时4.727971076965332秒
# 已经生成411张图片
# 耗时4.988977432250977秒
# 已经生成412张图片
# 耗时4.781311988830566秒
# 已经生成413张图片
# 耗时4.820852994918823秒
# 已经生成414张图片
# 耗时4.996162414550781秒
# 已经生成415张图片
# 耗时4.730243682861328秒
# 已经生成416张图片
# 耗时4.6732025146484375秒
# 已经生成417张图片
# 耗时5.387449264526367秒
# 已经生成418张图片
# 耗时5.477954864501953秒
# 已经生成419张图片
# 耗时4.735706567764282秒
# 已经生成420张图片
# 耗时5.185835838317871秒
# 已经生成421张图片
# 耗时5.002166271209717秒
# 已经生成422张图片
# 耗时5.4920008182525635秒
# 已经生成423张图片
# 耗时4.89780855178833秒
# 已经生成424张图片
# 耗时5.3321802616119385秒
# 已经生成425张图片
# 耗时5.283957481384277秒
# 已经生成426张图片
# 耗时4.9848082065582275秒
# 已经生成427张图片
# 耗时5.197360992431641秒
# 已经生成428张图片
# 耗时4.813258409500122秒
# 已经生成429张图片
# 耗时4.567424297332764秒
# 已经生成430张图片
# 耗时4.8018670082092285秒
# 已经生成431张图片
# 耗时5.055258750915527秒
# 已经生成432张图片
# 耗时4.759607315063477秒
# 已经生成433张图片
# 耗时4.769024610519409秒
# 已经生成434张图片
# 耗时6.211288928985596秒
# 已经生成435张图片
# 耗时5.175837755203247秒
# 已经生成436张图片
# 耗时5.018266916275024秒
# 已经生成437张图片
# 耗时5.13350510597229秒
# 已经生成438张图片
# 耗时5.068000316619873秒
# 已经生成439张图片
# 耗时4.966013431549072秒
# 已经生成440张图片
# 耗时5.222130060195923秒
# 已经生成441张图片
# 耗时4.774370908737183秒
# 已经生成442张图片
# 耗时4.60064172744751秒
# 已经生成443张图片
# 耗时4.827516794204712秒
# 已经生成444张图片
# 耗时4.819004774093628秒
# 已经生成445张图片
# 耗时4.78700590133667秒
# 已经生成446张图片
# 耗时4.712026596069336秒
# 已经生成447张图片
# 耗时4.6836700439453125秒
# 已经生成448张图片
# 耗时4.762279987335205秒
# 已经生成449张图片
# 耗时4.820458889007568秒
# 已经生成450张图片
# 耗时5.590245246887207秒
# 已经生成451张图片
# 耗时4.980352163314819秒
# 已经生成452张图片
# 耗时5.628012418746948秒
# 已经生成453张图片
# 耗时5.393527269363403秒
# 已经生成454张图片
# 耗时5.201042652130127秒
# 已经生成455张图片
# 耗时4.812438249588013秒
# 已经生成456张图片
# 耗时5.168369770050049秒
# 已经生成457张图片
# 耗时5.252176284790039秒
# 已经生成458张图片
# 耗时5.340626239776611秒
# 已经生成459张图片
# 耗时5.007078647613525秒
# 已经生成460张图片
# 耗时4.777451753616333秒
# 已经生成461张图片
# 耗时4.829541444778442秒
# 已经生成462张图片
# 耗时4.768140554428101秒
# 已经生成463张图片
# 耗时4.824878215789795秒
# 已经生成464张图片
# 耗时4.993993759155273秒
# 已经生成465张图片
# 耗时4.9478678703308105秒
# 已经生成466张图片
# 耗时4.871800184249878秒
# 已经生成467张图片
# 耗时4.774097681045532秒
# 已经生成468张图片
# 耗时4.795461177825928秒
# 已经生成469张图片
# 耗时4.9960854053497314秒
# 已经生成470张图片
# 耗时5.158945560455322秒
# 已经生成471张图片
# 耗时4.85402250289917秒
# 已经生成472张图片
# 耗时4.988662481307983秒
# 已经生成473张图片
# 耗时5.386760950088501秒
# 已经生成474张图片
# 耗时4.977345705032349秒
# 已经生成475张图片
# 耗时5.193407773971558秒
# 已经生成476张图片
# 耗时5.218510627746582秒
# 已经生成477张图片
# 耗时4.977890729904175秒
# 已经生成478张图片
# 耗时4.819944858551025秒
# 已经生成479张图片
# 耗时4.9367406368255615秒
# 已经生成480张图片
# 耗时5.271928548812866秒
# 已经生成481张图片
# 耗时5.591564178466797秒
# 已经生成482张图片
# 耗时5.3864006996154785秒
# 已经生成483张图片
# 耗时4.985145330429077秒
# 已经生成484张图片
# 耗时5.011627197265625秒
# 已经生成485张图片
# 耗时4.989264488220215秒
# 已经生成486张图片
# 耗时4.97808837890625秒
# 已经生成487张图片
# 耗时4.828112363815308秒
# 已经生成488张图片
# 耗时5.304500341415405秒
# 已经生成489张图片
# 耗时4.892611265182495秒
# 已经生成490张图片
# 耗时4.992816209793091秒
# 已经生成491张图片
# 耗时4.982247591018677秒
# 已经生成492张图片
# 耗时4.962117910385132秒
# 已经生成493张图片
# 耗时4.8367860317230225秒
# 已经生成494张图片
# 耗时5.213207483291626秒
# 已经生成495张图片
# 耗时4.7849977016448975秒
# 已经生成496张图片
# 耗时4.810163974761963秒
# 已经生成497张图片
# 耗时4.9943482875823975秒
# 已经生成498张图片
# 耗时4.994015216827393秒
# 已经生成499张图片
# 耗时5.207441806793213秒
# 已经生成500张图片
# 耗时5.5860371589660645秒
# 已经生成501张图片
# 耗时5.782083749771118秒
# 已经生成502张图片
# 耗时5.418473482131958秒
# 已经生成503张图片
# 耗时5.38675594329834秒
# 已经生成504张图片
# 耗时5.439605951309204秒
# 已经生成505张图片
# 耗时5.106934547424316秒
# 已经生成506张图片
# 耗时5.6557252407073975秒
# 已经生成507张图片
# 耗时5.595493316650391秒
# 已经生成508张图片
# 耗时6.587414264678955秒
# 已经生成509张图片
# 耗时4.983235836029053秒
# 已经生成510张图片
# 耗时5.1095616817474365秒
# 已经生成511张图片
# 耗时5.4707300662994385秒
# 已经生成512张图片
# 耗时5.270628213882446秒
# 已经生成513张图片
# 耗时5.135443210601807秒
# 已经生成514张图片
# 耗时5.194050550460815秒
# 已经生成515张图片
# 耗时5.180936336517334秒
# 已经生成516张图片
# 耗时5.24155592918396秒
# 已经生成517张图片
# 耗时5.189709424972534秒
# 已经生成518张图片
# 耗时5.307835102081299秒
# 已经生成519张图片
# 耗时5.286826848983765秒
# 已经生成520张图片
# 耗时5.197527647018433秒
# 已经生成521张图片
# 耗时5.401079893112183秒
# 已经生成522张图片
# 耗时4.98392128944397秒
# 已经生成523张图片
# 耗时5.2059526443481445秒
# 已经生成524张图片
# 耗时5.1196229457855225秒
# 已经生成525张图片
# 耗时5.256635904312134秒
# 已经生成526张图片
# 耗时4.7997047901153564秒
# 已经生成527张图片
# 耗时5.018260478973389秒
# 已经生成528张图片
# 耗时4.737289190292358秒
# 已经生成529张图片
# 耗时5.047224760055542秒
# 已经生成530张图片
# 耗时5.126647233963013秒
# 已经生成531张图片
# 耗时5.050387859344482秒
# 已经生成532张图片
# 耗时4.77831244468689秒
# 已经生成533张图片
# 耗时5.1829986572265625秒
# 已经生成534张图片
# 耗时5.0465922355651855秒
# 已经生成535张图片
# 耗时5.192056894302368秒
# 已经生成536张图片
# 耗时5.001312494277954秒
# 已经生成537张图片
# 耗时5.798144817352295秒
# 已经生成538张图片
# 耗时5.1794726848602295秒
# 已经生成539张图片
# 耗时4.8208630084991455秒
# 已经生成540张图片
# 耗时5.180274963378906秒
# 已经生成541张图片
# 耗时4.784257888793945秒
# 已经生成542张图片
# 耗时5.192501068115234秒
# 已经生成543张图片
# 耗时5.2221479415893555秒
# 已经生成544张图片
# 耗时5.230252265930176秒
# 已经生成545张图片
# 耗时4.976926326751709秒
# 已经生成546张图片
# 耗时5.203248500823975秒
# 已经生成547张图片
# 耗时5.426530122756958秒
# 已经生成548张图片
# 耗时5.135595321655273秒
# 已经生成549张图片
# 耗时5.075617790222168秒
# 已经生成550张图片
# 耗时4.934904098510742秒
# 已经生成551张图片
# 耗时4.7946600914001465秒
# 已经生成552张图片
# 耗时4.987368106842041秒
# 已经生成553张图片
# 耗时4.933325529098511秒
# 已经生成554张图片
# 耗时4.869690418243408秒
# 已经生成555张图片
# 耗时4.787359237670898秒
# 已经生成556张图片
# 耗时5.0093770027160645秒
# 已经生成557张图片
# 耗时4.818783760070801秒
# 已经生成558张图片
# 耗时4.774881601333618秒
# 已经生成559张图片
# 耗时4.802537441253662秒
# 已经生成560张图片
# 耗时5.103512287139893秒
# 已经生成561张图片
# 耗时4.8967461585998535秒
# 已经生成562张图片
# 耗时4.779881954193115秒
# 已经生成563张图片
# 耗时5.013343334197998秒
# 已经生成564张图片
# 耗时4.982701301574707秒
# 已经生成565张图片
# 耗时4.991002798080444秒
# 已经生成566张图片
# 耗时4.995772361755371秒
# 已经生成567张图片
# 耗时4.8263044357299805秒
# 已经生成568张图片
# 耗时5.056579828262329秒
# 已经生成569张图片
# 耗时4.932467460632324秒
# 已经生成570张图片
# 耗时5.606732368469238秒
# 已经生成571张图片
# 耗时5.194376707077026秒
# 已经生成572张图片
# 耗时5.796279430389404秒
# 已经生成573张图片
# 耗时5.208381652832031秒
# 已经生成574张图片
# 耗时5.60258150100708秒
# 已经生成575张图片
# 耗时5.193289041519165秒
# 已经生成576张图片
# 耗时5.494206190109253秒
# 已经生成577张图片
# 耗时5.089122772216797秒
# 已经生成578张图片
# 耗时5.394164800643921秒
# 已经生成579张图片
# 耗时5.604496955871582秒
# 已经生成580张图片
# 耗时5.202788352966309秒
# 已经生成581张图片
# 耗时5.592072486877441秒
# 已经生成582张图片
# 耗时5.200932502746582秒
# 已经生成583张图片
# 耗时5.1994898319244385秒
# 已经生成584张图片
# 耗时5.423835277557373秒
# 已经生成585张图片
# 耗时5.970654726028442秒
# 已经生成586张图片
# 耗时5.232083559036255秒
# 已经生成587张图片
# 耗时5.600928783416748秒
# 已经生成588张图片
# 耗时5.376736879348755秒
# 已经生成589张图片
# 耗时5.369824647903442秒
# 已经生成590张图片
# 耗时5.005334138870239秒
# 已经生成591张图片
# 耗时5.160201072692871秒
# 已经生成592张图片
# 耗时5.039577960968018秒
# 已经生成593张图片
# 耗时5.174854516983032秒
# 已经生成594张图片
# 耗时5.2198545932769775秒
# 已经生成595张图片
# 耗时5.186593532562256秒
# 已经生成596张图片
# 耗时4.96668815612793秒
# 已经生成597张图片
# 耗时5.045707941055298秒
# 已经生成598张图片
# 耗时5.209485769271851秒
# 已经生成599张图片
# 耗时5.1703715324401855秒
# 已经生成600张图片
# 耗时4.990196228027344秒
# 已经生成601张图片
# 耗时5.010434150695801秒
# 已经生成602张图片
# 耗时5.167899131774902秒
# 已经生成603张图片
# 耗时5.2277350425720215秒
# 已经生成604张图片
# 耗时4.951245307922363秒
# 已经生成605张图片
# 耗时5.047239303588867秒
# 已经生成606张图片
# 耗时4.997407913208008秒
# 已经生成607张图片
# 耗时4.963001728057861秒
# 已经生成608张图片
# 耗时5.034361362457275秒
# 已经生成609张图片
# 耗时5.000089645385742秒
# 已经生成610张图片
# 耗时5.142564058303833秒
# 已经生成611张图片
# 耗时5.234643220901489秒
# 已经生成612张图片
# 耗时5.393403053283691秒
# 已经生成613张图片
# 耗时5.196023225784302秒
# 已经生成614张图片
# 耗时5.598525524139404秒
# 已经生成615张图片
# 耗时5.408699989318848秒
# 已经生成616张图片
# 耗时5.1960344314575195秒
# 已经生成617张图片
# 耗时5.375695466995239秒
# 已经生成618张图片
# 耗时5.188028812408447秒
# 已经生成619张图片
# 耗时5.420995712280273秒
# 已经生成620张图片
# 耗时5.392750263214111秒
# 已经生成621张图片
# 耗时5.410135507583618秒
# 已经生成622张图片
# 耗时5.1994383335113525秒
# 已经生成623张图片
# 耗时4.98722243309021秒
# 已经生成624张图片
# 耗时5.018225431442261秒
# 已经生成625张图片
# 耗时4.989273548126221秒
# 已经生成626张图片
# 耗时5.1809751987457275秒
# 已经生成627张图片
# 耗时4.975470781326294秒
# 已经生成628张图片
# 耗时5.024828195571899秒
# 已经生成629张图片
# 耗时5.004377603530884秒
# 已经生成630张图片
# 耗时4.975769519805908秒
# 已经生成631张图片
# 耗时5.417755126953125秒
# 已经生成632张图片
# 耗时5.198729991912842秒
# 已经生成633张图片
# 耗时4.986460447311401秒
# 已经生成634张图片
# 耗时4.991247653961182秒
# 已经生成635张图片
# 耗时5.211422443389893秒
# 已经生成636张图片
# 耗时5.443178653717041秒
# 已经生成637张图片
# 耗时5.745381832122803秒
# 已经生成638张图片
# 耗时5.191260576248169秒
# 已经生成639张图片
# 耗时5.186572074890137秒
# 已经生成640张图片
# 耗时5.207107782363892秒
# 已经生成641张图片
# 耗时5.171766996383667秒
# 已经生成642张图片
# 耗时4.993585109710693秒
# 已经生成643张图片
# 耗时4.7732439041137695秒
# 已经生成644张图片
# 耗时5.194011211395264秒
# 已经生成645张图片
# 耗时5.033857345581055秒
# 已经生成646张图片
# 耗时5.024716854095459秒
# 已经生成647张图片
# 耗时4.98008131980896秒
# 已经生成648张图片
# 耗时5.0032126903533936秒
# 已经生成649张图片
# 耗时5.013942241668701秒
# 已经生成650张图片
# 耗时4.945042133331299秒
# 已经生成651张图片
# 耗时4.86843729019165秒
# 已经生成652张图片
# 耗时4.789383411407471秒
# 已经生成653张图片
# 耗时4.990292310714722秒
# 已经生成654张图片
# 耗时4.991903066635132秒
# 已经生成655张图片
# 耗时4.783522129058838秒
# 已经生成656张图片
# 耗时4.82837176322937秒
# 已经生成657张图片
# 耗时4.937265396118164秒
# 已经生成658张图片
# 耗时5.04928994178772秒
# 已经生成659张图片
# 耗时4.991028547286987秒
# 已经生成660张图片
# 耗时4.9684669971466064秒
# 已经生成661张图片
# 耗时4.834367036819458秒
# 已经生成662张图片
# 耗时4.993102073669434秒
# 已经生成663张图片
# 耗时5.0047447681427秒
# 已经生成664张图片
# 耗时5.376048564910889秒
# 已经生成665张图片
# 耗时5.642702341079712秒
# 已经生成666张图片
# 耗时5.000438928604126秒
# 已经生成667张图片
# 耗时5.17217230796814秒
# 已经生成668张图片
# 耗时5.172806739807129秒
# 已经生成669张图片
# 耗时4.984267473220825秒
# 已经生成670张图片
# 耗时5.613319396972656秒
# 已经生成671张图片
# 耗时5.379819631576538秒
# 已经生成672张图片
# 耗时5.227280616760254秒
# 已经生成673张图片
# 耗时5.211580753326416秒
# 已经生成674张图片
# 耗时4.9382617473602295秒
# 已经生成675张图片
# 耗时5.089839696884155秒
# 已经生成676张图片
# 耗时5.191334962844849秒
# 已经生成677张图片
# 耗时5.00194787979126秒
# 已经生成678张图片
# 耗时5.271963357925415秒
# 已经生成679张图片
# 耗时5.553781509399414秒
# 已经生成680张图片
# 耗时5.236555814743042秒
# 已经生成681张图片
# 耗时5.3905417919158936秒
# 已经生成682张图片
# 耗时5.410876274108887秒
# 已经生成683张图片
# 耗时4.9648277759552秒
# 已经生成684张图片
# 耗时4.987932443618774秒
# 已经生成685张图片
# 耗时4.996786117553711秒
# 已经生成686张图片
# 耗时5.019304275512695秒
# 已经生成687张图片
# 耗时5.208434820175171秒
# 已经生成688张图片
# 耗时5.168023586273193秒
# 已经生成689张图片
# 耗时5.171133041381836秒
# 已经生成690张图片
# 耗时5.025403022766113秒
# 已经生成691张图片
# 耗时5.606212139129639秒
# 已经生成692张图片
# 耗时5.190409421920776秒
# 已经生成693张图片
# 耗时5.148918390274048秒
# 已经生成694张图片
# 耗时5.249997615814209秒
# 已经生成695张图片
# 耗时5.004895210266113秒
# 已经生成696张图片
# 耗时5.189831018447876秒
# 已经生成697张图片
# 耗时5.1927502155303955秒
# 已经生成698张图片
# 耗时5.386302471160889秒
# 已经生成699张图片
# 耗时4.991227626800537秒
# 已经生成700张图片
# 耗时5.031781911849976秒
# 已经生成701张图片
# 耗时5.1883790493011475秒
# 已经生成702张图片
# 耗时5.204375505447388秒
# 已经生成703张图片
# 耗时5.116961479187012秒
# 已经生成704张图片
# 耗时5.06505012512207秒
# 已经生成705张图片
# 耗时5.153111934661865秒
# 已经生成706张图片
# 耗时5.036342620849609秒
# 已经生成707张图片
# 耗时5.185121536254883秒
# 已经生成708张图片
# 耗时5.223163604736328秒
# 已经生成709张图片
# 耗时6.283387899398804秒
# 已经生成710张图片
# 耗时5.32799220085144秒
# 已经生成711张图片
# 耗时5.57878851890564秒
# 已经生成712张图片
# 耗时5.175207853317261秒
# 已经生成713张图片
# 耗时5.239529132843018秒
# 已经生成714张图片
# 耗时5.371974468231201秒
# 已经生成715张图片
# 耗时5.217791557312012秒
# 已经生成716张图片
# 耗时5.148325443267822秒
# 已经生成717张图片
# 耗时5.234156131744385秒
# 已经生成718张图片
# 耗时5.206681728363037秒
# 已经生成719张图片
# 耗时5.439316511154175秒
# 已经生成720张图片
# 耗时5.133665084838867秒
# 已经生成721张图片
# 耗时5.052212953567505秒
# 已经生成722张图片
# 耗时5.171082973480225秒
# 已经生成723张图片
# 耗时4.9756529331207275秒
# 已经生成724张图片
# 耗时4.996724367141724秒
# 已经生成725张图片
# 耗时5.018743515014648秒
# 已经生成726张图片
# 耗时5.190407991409302秒
# 已经生成727张图片
# 耗时5.195963144302368秒
# 已经生成728张图片
# 耗时4.972742795944214秒
# 已经生成729张图片
# 耗时5.24825382232666秒
# 已经生成730张图片
# 耗时5.165720701217651秒
# 已经生成731张图片
# 耗时5.638171672821045秒
# 已经生成732张图片
# 耗时5.356282711029053秒
# 已经生成733张图片
# 耗时4.981159210205078秒
# 已经生成734张图片
# 耗时5.030400991439819秒
# 已经生成735张图片
# 耗时4.984450817108154秒
# 已经生成736张图片
# 耗时5.383487701416016秒
# 已经生成737张图片
# 耗时5.164485216140747秒
# 已经生成738张图片
# 耗时5.065136909484863秒
# 已经生成739张图片
# 耗时5.156464099884033秒
# 已经生成740张图片
