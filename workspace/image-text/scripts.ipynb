# %% [markdown]
# ## img-text-img
#
# 此文件的作用是使用img2text，然后再拼接上自定义的风格词，然后再次出图片

# %%
import json
from urllib import request, parse
import random
import uuid
import urllib.request
import urllib.parse
import io
import os
import time
from PIL.PngImagePlugin import PngInfo
import hashlib
from urllib.error import URLError

# %% [markdown]
# ## import json file

# %%
promptJson = 'api.json'

with open(promptJson) as f:
    prompt = json.load(f)

# %%
from enum import Enum, unique

@unique
class RunMode(Enum):
    LOCAL = 1
    POD_LOCAL = 2
    POD_REMOTE = 3

run_mode = RunMode.LOCAL
# 设置运行模式，来实现在本机，runpod本地，runpod远程的切换
server_address = "2bzezpggl7sjvi-3000.proxy.runpod.net/" if run_mode == RunMode.POD_REMOTE else "0.0.0.0:3000" if run_mode == RunMode.POD_LOCAL else "127.0.0.1:8188"
client_id = str(uuid.uuid4())

# %%
def changeImageSize(width, height):
    # 最小的宽高为本机896，runpod1024
    limited = 896 if run_mode == RunMode.LOCAL else 1024
    minSize = min(width, height)

    # 缩放宽高，使得最窄的边等于limited
    if minSize > limited:
        scale = minSize / limited
        widthScale = int(width / scale)
        heightScale = int(height / scale)
    else:
        scale = limited / minSize
        widthScale = int(width * scale)
        heightScale = int(height * scale)

    # 将两个值都除以64，然后取整,也就是说边长必须是64的倍数
    widthScale = int(widthScale/64) * 64
    heightScale = int(heightScale/64) * 64

    return widthScale, heightScale

def checkImageExsit(imageDir, imageName):
    for file in os.listdir(imageDir):
        if file.startswith(imageName):
            return True
    return False


def queue_prompt(prompt):
    while True:
        try:
            p = {"prompt": prompt, "client_id": client_id}
            data = json.dumps(p).encode('utf-8')
            req = urllib.request.Request("http://{}/prompt".format(server_address), data=data)
            return json.loads(urllib.request.urlopen(req, timeout=5).read())
        except URLError:
            print("连接超时，正在重试...")

def get_history(prompt_id):
    with urllib.request.urlopen("http://{}/history/{}".format(server_address, prompt_id)) as response:
        return json.loads(response.read())

def get_image(filename, subfolder, folder_type):
    data = {"filename": filename, "subfolder": subfolder, "type": folder_type}
    url_values = urllib.parse.urlencode(data)
    with urllib.request.urlopen("http://{}/view?{}".format(server_address, url_values)) as response:
        return response.read()

def handle_whitespace(string: str):
    return string.strip().replace("\n", " ").replace("\r", " ").replace("\t", " ")

def parse_name(ckpt_name):
    path = ckpt_name
    filename = path.split("/")[-1]
    filename = filename.split(".")[:-1]
    filename = ".".join(filename)
    return filename


def calculate_sha256(file_path):
    sha256_hash = hashlib.sha256()

    with open(file_path, "rb") as f:
        # Read the file in chunks to avoid loading the entire file into memory
        for byte_block in iter(lambda: f.read(4096), b""):
            sha256_hash.update(byte_block)

    return sha256_hash.hexdigest()

def get_images(ws, prompt):
    prompt_id = queue_prompt(prompt)['prompt_id']
    output_images = {}
    while True:
        out = ws.recv()
        if isinstance(out, str):
            message = json.loads(out)
            if message['type'] == 'executing':
                data = message['data']
                if data['node'] is None and data['prompt_id'] == prompt_id:
                    break #Execution is done
        else:
            continue #previews are binary data

    history = get_history(prompt_id)[prompt_id]
    for o in history['outputs']:
        for node_id in history['outputs']:
            node_output = history['outputs'][node_id]
            if 'images' in node_output:
                images_output = []
                for image in node_output['images']:
                    image_data = get_image(image['filename'], image['subfolder'], image['type'])
                    images_output.append(image_data)
                output_images[node_id] = images_output

    return output_images
    
def saveImages(result, imageDir,imageName,comment,previewImage=0): 
    metadata = PngInfo()
    metadata.add_text("parameters", comment)  
    k = 0 
    for node_id in result:    
        if k < previewImage:
            k += 1
            continue    
        for image_data in result[node_id]:            
            image = Image.open(io.BytesIO(image_data))
            imagePath = imageDir + "/" + imageName + f"_{k}" + ".png"
            image.save(imagePath,pnginfo=metadata) 
            k += 1

def saveTags(ws, prompt, textDir, originalImagName):
    prompt_id = queue_prompt(prompt)['prompt_id']
    while True:
        out = ws.recv()
        if isinstance(out, str):
            message = json.loads(out)
            if message['type'] == 'executing':
                data = message['data']
                if data['node'] is None and data['prompt_id'] == prompt_id:
                    break #Execution is done
        else:
            continue #previews are binary data

    history = get_history(prompt_id)[prompt_id]
    for node_id in history['outputs']:
        node_output = history['outputs'][node_id]
        print(node_output)
        if 'tags' in node_output:
            tags = node_output['tags']
            with open(textDir + "/" + originalImagName + ".txt", "w") as f:
                for tag in tags:
                    f.write(tag + "\n")

# %%
# 子文件夹
subDir = "BoA"

# 原图文件夹
originalDir = f"f:/Poledriver/Paid/{subDir}" if run_mode != RunMode.POD_LOCAL else f"../../../image-inputs/{subDir}"
# 设置文本保存路径
textDir = originalDir + '-text'
# 如果文件夹不存在，创建文件夹
if not os.path.exists(textDir):
    os.mkdir(textDir)

# %%
from PIL import Image
# %pip install sd-parsers
from sdparsers import ParserManager
import websocket

ws = websocket.WebSocket()
ws.connect("ws://{}/ws?clientId={}".format(server_address, client_id))

batch_size = 4
# 遍历原图文件夹里所有的图片
for originalImag in os.listdir(originalDir):
        # 如果不是jpg或png文件，跳过
        if not (originalImag.endswith(".jpg") or originalImag.endswith(".png") or originalImag.endswith(".jpeg")):
            continue
        
        originalImagePath = originalDir + "/" + originalImag
        # 如果文件名包含_H或者_B，跳过
        if originalImag.find("_H") != -1 or originalImag.find("_B") != -1:
            print(f"{originalImag}包含_H或者_B,判定为mask文件，跳过")
            continue
        
        # 读取原图片名字，去掉后缀.png
        originalImagName = originalImag.split(".")[0]
        # 检测目标文件夹里是否已经存在该图片，如果存在，跳过
        if checkImageExsit(textDir, originalImagName):
            continue 
        
        prompt['44']['inputs']['image'] = originalImagePath
        
        # 连接api，生成并保存图片
        start_time = time.time()        
        # images = get_images(ws, prompt)
        saveTags(ws, prompt, textDir, originalImagName)                    
        
        end_time = time.time()
        print(f"耗时{end_time-start_time}秒")
# Out:
# Requirement already satisfied: sd-parsers in e:\stable-diffusion-api-test\.venv\lib\site-packages (0.2.3)
# Requirement already satisfied: Pillow>=8.3.1 in e:\stable-diffusion-api-test\.venv\lib\site-packages (from sd-parsers) (10.0.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, black_hair, bow, navel, sitting, closed_mouth, nipples, braid, hair_bow, nude, glasses, pussy, indoors, spread_legs, black_eyes, twin_braids, flat_chest, lips, loli, completely_nude, window, uncensored, black-framed_eyewear']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, black_hair, bow, navel, sitting, closed_mouth, nipples, braid, hair_bow, nude, glasses, pussy, indoors, spread_legs, black_eyes, twin_braids, flat_chest, lips, loli, completely_nude, window, uncensored, black-framed_eyewear']}
# 耗时1.674680471420288秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, smile, bangs, black_hair, navel, twintails, sitting, closed_mouth, nipples, collarbone, braid, nude, glasses, pussy, indoors, spread_legs, twin_braids, flat_chest, lips, parted_bangs, loli, completely_nude, arm_support, black-framed_eyewear, hair_tie, on_floor']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, smile, bangs, black_hair, navel, twintails, sitting, closed_mouth, nipples, collarbone, braid, nude, glasses, pussy, indoors, spread_legs, twin_braids, flat_chest, lips, parted_bangs, loli, completely_nude, arm_support, black-framed_eyewear, hair_tie, on_floor']}
# 耗时1.6866166591644287秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, blue_eyes, black_hair, navel, closed_mouth, nipples, collarbone, braid, nude, censored, glasses, barefoot, pussy, spread_legs, twin_braids, flat_chest, feet, lips, pubic_hair, loli, completely_nude, uncensored, arm_support, female_pubic_hair, arms_behind_back, squatting, black-framed_eyewear, hair_tie, leaning_back']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, blue_eyes, black_hair, navel, closed_mouth, nipples, collarbone, braid, nude, censored, glasses, barefoot, pussy, spread_legs, twin_braids, flat_chest, feet, lips, pubic_hair, loli, completely_nude, uncensored, arm_support, female_pubic_hair, arms_behind_back, squatting, black-framed_eyewear, hair_tie, leaning_back']}
# 耗时1.6951136589050293秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, bangs, black_hair, hair_ornament, navel, brown_eyes, sitting, nipples, braid, nude, censored, parted_lips, glasses, pussy, hairclip, spread_legs, mosaic_censoring, twin_braids, flat_chest, loli, completely_nude, pussy_juice, semi-rimless_eyewear, spread_pussy, under-rim_eyewear']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, bangs, black_hair, hair_ornament, navel, brown_eyes, sitting, nipples, braid, nude, censored, parted_lips, glasses, pussy, hairclip, spread_legs, mosaic_censoring, twin_braids, flat_chest, loli, completely_nude, pussy_juice, semi-rimless_eyewear, spread_pussy, under-rim_eyewear']}
# 耗时1.7341375350952148秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, bangs, skirt, black_hair, twintails, sitting, closed_mouth, nipples, collarbone, braid, pleated_skirt, outdoors, censored, sky, glasses, pussy, spread_legs, mosaic_censoring, twin_braids, flat_chest, tree, lips, plaid, loli, no_panties, night, plaid_skirt, topless, skirt_lift, moon, grass, night_sky, bandaid, full_moon, black-framed_eyewear, bench']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, bangs, skirt, black_hair, twintails, sitting, closed_mouth, nipples, collarbone, braid, pleated_skirt, outdoors, censored, sky, glasses, pussy, spread_legs, mosaic_censoring, twin_braids, flat_chest, tree, lips, plaid, loli, no_panties, night, plaid_skirt, topless, skirt_lift, moon, grass, night_sky, bandaid, full_moon, black-framed_eyewear, bench']}
# 耗时1.6896061897277832秒
# {'tags': ['1girl, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, 1boy, navel, closed_mouth, nipples, braid, hetero, nude, small_breasts, lying, censored, penis, glasses, pussy, solo_focus, shiny, spread_legs, cum, sex, on_back, armpits, water, black_eyes, mosaic_censoring, vaginal, twin_braids, flat_chest, wet, shiny_skin, loli, completely_nude, pov, partially_submerged, missionary, ribs, mixed_bathing, blue-framed_eyewear']}
# {'text': ['1girl, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, 1boy, navel, closed_mouth, nipples, braid, hetero, nude, small_breasts, lying, censored, penis, glasses, pussy, solo_focus, shiny, spread_legs, cum, sex, on_back, armpits, water, black_eyes, mosaic_censoring, vaginal, twin_braids, flat_chest, wet, shiny_skin, loli, completely_nude, pov, partially_submerged, missionary, ribs, mixed_bathing, blue-framed_eyewear']}
# 耗时1.8051927089691162秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, blue_eyes, black_hair, navel, sitting, closed_mouth, nipples, collarbone, braid, nude, sweat, censored, glasses, pussy, indoors, spread_legs, mosaic_censoring, twin_braids, flat_chest, lips, loli, completely_nude, arm_support, hair_over_shoulder']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, blue_eyes, black_hair, navel, sitting, closed_mouth, nipples, collarbone, braid, nude, sweat, censored, glasses, pussy, indoors, spread_legs, mosaic_censoring, twin_braids, flat_chest, lips, loli, completely_nude, arm_support, hair_over_shoulder']}
# 耗时1.7478711605072021秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, bangs, shirt, black_hair, long_sleeves, navel, sitting, closed_mouth, nipples, braid, small_breasts, censored, open_clothes, glasses, pussy, indoors, spread_legs, off_shoulder, black_eyes, mosaic_censoring, twin_braids, flat_chest, black_shirt, loli, open_shirt, no_panties, bottomless, black-framed_eyewear, wooden_floor']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, bangs, shirt, black_hair, long_sleeves, navel, sitting, closed_mouth, nipples, braid, small_breasts, censored, open_clothes, glasses, pussy, indoors, spread_legs, off_shoulder, black_eyes, mosaic_censoring, twin_braids, flat_chest, black_shirt, loli, open_shirt, no_panties, bottomless, black-framed_eyewear, wooden_floor']}
# 耗时1.7192082405090332秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, hair_ornament, bow, navel, sitting, nipples, collarbone, braid, nude, sweat, small_breasts, censored, parted_lips, glasses, pussy, hairclip, shiny, indoors, spread_legs, bowtie, black_eyes, mosaic_censoring, red_bow, twin_braids, shiny_skin, loli, completely_nude, detached_collar, arm_support, table, red_bowtie, semi-rimless_eyewear, black-framed_eyewear, spread_pussy, under-rim_eyewear, hair_tie']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, hair_ornament, bow, navel, sitting, nipples, collarbone, braid, nude, sweat, small_breasts, censored, parted_lips, glasses, pussy, hairclip, shiny, indoors, spread_legs, bowtie, black_eyes, mosaic_censoring, red_bow, twin_braids, shiny_skin, loli, completely_nude, detached_collar, arm_support, table, red_bowtie, semi-rimless_eyewear, black-framed_eyewear, spread_pussy, under-rim_eyewear, hair_tie']}
# 耗时1.7425920963287354秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, bangs, skirt, black_hair, navel, sitting, closed_mouth, nipples, collarbone, braid, pleated_skirt, small_breasts, outdoors, censored, sky, glasses, pussy, spread_legs, miniskirt, twin_braids, flat_chest, lips, plaid, loli, no_panties, night, plaid_skirt, topless, star_\\(sky\\), night_sky, hair_over_shoulder, hair_tie']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, bangs, skirt, black_hair, navel, sitting, closed_mouth, nipples, collarbone, braid, pleated_skirt, small_breasts, outdoors, censored, sky, glasses, pussy, spread_legs, miniskirt, twin_braids, flat_chest, lips, plaid, loli, no_panties, night, plaid_skirt, topless, star_\\(sky\\), night_sky, hair_over_shoulder, hair_tie']}
# 耗时1.7392604351043701秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, skirt, black_hair, twintails, sitting, closed_mouth, collarbone, swimsuit, braid, bikini, small_breasts, outdoors, censored, glasses, pussy, day, spread_legs, black_skirt, water, clothes_lift, black_eyes, mosaic_censoring, twin_braids, flat_chest, maid_headdress, bare_arms, anus, black_bikini, side-tie_bikini_bottom, skirt_lift, plant, lifted_by_self, bikini_top_only, black-framed_eyewear, pool, untied_bikini']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, skirt, black_hair, twintails, sitting, closed_mouth, collarbone, swimsuit, braid, bikini, small_breasts, outdoors, censored, glasses, pussy, day, spread_legs, black_skirt, water, clothes_lift, black_eyes, mosaic_censoring, twin_braids, flat_chest, maid_headdress, bare_arms, anus, black_bikini, side-tie_bikini_bottom, skirt_lift, plant, lifted_by_self, bikini_top_only, black-framed_eyewear, pool, untied_bikini']}
# 耗时1.8025610446929932秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, bangs, black_hair, twintails, sitting, closed_mouth, collarbone, braid, glasses, pussy, sleeveless, indoors, spread_legs, mole, twin_braids, flat_chest, head_tilt, loli, window, uncensored, bottomless, arm_support, camisole, black-framed_eyewear, hair_tie']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, bangs, black_hair, twintails, sitting, closed_mouth, collarbone, braid, glasses, pussy, sleeveless, indoors, spread_legs, mole, twin_braids, flat_chest, head_tilt, loli, window, uncensored, bottomless, arm_support, camisole, black-framed_eyewear, hair_tie']}
# 耗时1.7141478061676025秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, open_mouth, bangs, blue_eyes, black_hair, navel, bare_shoulders, twintails, collarbone, swimsuit, braid, bikini, sweat, frills, glasses, barefoot, choker, indoors, spread_legs, twin_braids, flat_chest, loli, window, pussy_juice, black_bikini, bottomless, black_choker, piercing, squatting, bikini_top_only, semi-rimless_eyewear, masturbation, frilled_bikini, black-framed_eyewear, female_masturbation, steaming_body, tiptoes, navel_piercing']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, open_mouth, bangs, blue_eyes, black_hair, navel, bare_shoulders, twintails, collarbone, swimsuit, braid, bikini, sweat, frills, glasses, barefoot, choker, indoors, spread_legs, twin_braids, flat_chest, loli, window, pussy_juice, black_bikini, bottomless, black_choker, piercing, squatting, bikini_top_only, semi-rimless_eyewear, masturbation, frilled_bikini, black-framed_eyewear, female_masturbation, steaming_body, tiptoes, navel_piercing']}
# 耗时1.6376957893371582秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, bangs, blue_eyes, black_hair, bow, navel, nipples, collarbone, braid, hair_bow, nude, sweat, censored, glasses, barefoot, pussy, indoors, spread_legs, cum, blunt_bangs, mosaic_censoring, twin_braids, flat_chest, loli, completely_nude, cum_in_pussy, squatting, cum_on_body, pink_bow, after_sex, black-framed_eyewear, cumdrip, spread_pussy, after_vaginal, stained_glass']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, bangs, blue_eyes, black_hair, bow, navel, nipples, collarbone, braid, hair_bow, nude, sweat, censored, glasses, barefoot, pussy, indoors, spread_legs, cum, blunt_bangs, mosaic_censoring, twin_braids, flat_chest, loli, completely_nude, cum_in_pussy, squatting, cum_on_body, pink_bow, after_sex, black-framed_eyewear, cumdrip, spread_pussy, after_vaginal, stained_glass']}
# 耗时1.840047836303711秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, skirt, black_hair, navel, brown_eyes, sitting, underwear, collarbone, braid, pleated_skirt, outdoors, censored, parted_lips, sky, glasses, pussy, spread_legs, miniskirt, bra, mosaic_censoring, twin_braids, flat_chest, plaid, bare_arms, no_panties, night, plaid_skirt, black-framed_eyewear, microskirt, plaid_bikini, plaid_bra']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, skirt, black_hair, navel, brown_eyes, sitting, underwear, collarbone, braid, pleated_skirt, outdoors, censored, parted_lips, sky, glasses, pussy, spread_legs, miniskirt, bra, mosaic_censoring, twin_braids, flat_chest, plaid, bare_arms, no_panties, night, plaid_skirt, black-framed_eyewear, microskirt, plaid_bikini, plaid_bra']}
# 耗时1.7666535377502441秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, bangs, skirt, black_hair, navel, bare_shoulders, twintails, brown_eyes, sitting, closed_mouth, collarbone, swimsuit, braid, bikini, censored, frills, glasses, pussy, choker, day, indoors, spread_legs, black_skirt, black_eyes, mosaic_censoring, twin_braids, flat_chest, maid_headdress, pussy_juice, no_panties, black_bikini, light_smile, plant, frilled_bikini, black-framed_eyewear, spread_pussy, bikini_skirt']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, bangs, skirt, black_hair, navel, bare_shoulders, twintails, brown_eyes, sitting, closed_mouth, collarbone, swimsuit, braid, bikini, censored, frills, glasses, pussy, choker, day, indoors, spread_legs, black_skirt, black_eyes, mosaic_censoring, twin_braids, flat_chest, maid_headdress, pussy_juice, no_panties, black_bikini, light_smile, plant, frilled_bikini, black-framed_eyewear, spread_pussy, bikini_skirt']}
# 耗时2.0881130695343018秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, bangs, black_hair, navel, twintails, sitting, closed_mouth, nipples, braid, nude, small_breasts, glasses, pussy, indoors, black_eyes, twin_braids, flat_chest, loli, completely_nude']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, bangs, black_hair, navel, twintails, sitting, closed_mouth, nipples, braid, nude, small_breasts, glasses, pussy, indoors, black_eyes, twin_braids, flat_chest, loli, completely_nude']}
# 耗时1.7573251724243164秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, bangs, black_hair, navel, twintails, closed_mouth, nipples, collarbone, braid, nude, sweat, censored, glasses, pussy, indoors, black_eyes, twin_braids, flat_chest, lips, loli, completely_nude, bar_censor, window, kneeling, black-framed_eyewear, hair_tie']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, bangs, black_hair, navel, twintails, closed_mouth, nipples, collarbone, braid, nude, sweat, censored, glasses, pussy, indoors, black_eyes, twin_braids, flat_chest, lips, loli, completely_nude, bar_censor, window, kneeling, black-framed_eyewear, hair_tie']}
# 耗时1.7801051139831543秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, navel, nipples, braid, nude, censored, parted_lips, shoes, glasses, pussy, socks, indoors, spread_legs, cum, blunt_bangs, black_footwear, mosaic_censoring, twin_braids, flat_chest, loli, completely_nude, cum_in_pussy, squatting, cum_on_body, pink_bow, after_sex, cumdrip, spread_pussy, after_vaginal']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, navel, nipples, braid, nude, censored, parted_lips, shoes, glasses, pussy, socks, indoors, spread_legs, cum, blunt_bangs, black_footwear, mosaic_censoring, twin_braids, flat_chest, loli, completely_nude, cum_in_pussy, squatting, cum_on_body, pink_bow, after_sex, cumdrip, spread_pussy, after_vaginal']}
# 耗时1.920698881149292秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, skirt, black_hair, navel, closed_mouth, underwear, braid, small_breasts, outdoors, censored, glasses, pussy, clothes_lift, bra, black_eyes, mosaic_censoring, twin_braids, flat_chest, plaid, bare_arms, loli, no_panties, plaid_skirt, skirt_lift, lifted_by_self, white_bra, training_bra']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, skirt, black_hair, navel, closed_mouth, underwear, braid, small_breasts, outdoors, censored, glasses, pussy, clothes_lift, bra, black_eyes, mosaic_censoring, twin_braids, flat_chest, plaid, bare_arms, loli, no_panties, plaid_skirt, skirt_lift, lifted_by_self, white_bra, training_bra']}
# 耗时1.7659597396850586秒
# {'tags': ['1girl, long_hair, looking_at_viewer, blush, smile, bangs, black_hair, 1boy, navel, twintails, brown_eyes, closed_mouth, nipples, braid, hetero, nude, censored, penis, glasses, pussy, solo_focus, spread_legs, sex, armpits, water, mole, mosaic_censoring, vaginal, twin_braids, flat_chest, wet, loli, completely_nude, pov, hair_over_shoulder, partially_submerged, blue-framed_eyewear']}
# {'text': ['1girl, long_hair, looking_at_viewer, blush, smile, bangs, black_hair, 1boy, navel, twintails, brown_eyes, closed_mouth, nipples, braid, hetero, nude, censored, penis, glasses, pussy, solo_focus, spread_legs, sex, armpits, water, mole, mosaic_censoring, vaginal, twin_braids, flat_chest, wet, loli, completely_nude, pov, hair_over_shoulder, partially_submerged, blue-framed_eyewear']}
# 耗时1.8668856620788574秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, open_mouth, bangs, black_hair, bow, navel, sitting, very_long_hair, nipples, braid, hair_bow, nude, censored, glasses, pussy, choker, indoors, spread_legs, blunt_bangs, mosaic_censoring, twin_braids, flat_chest, loli, pussy_juice, pink_bow, semi-rimless_eyewear, black-framed_eyewear, under-rim_eyewear, wooden_floor, door, bridal_garter']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, open_mouth, bangs, black_hair, bow, navel, sitting, very_long_hair, nipples, braid, hair_bow, nude, censored, glasses, pussy, choker, indoors, spread_legs, blunt_bangs, mosaic_censoring, twin_braids, flat_chest, loli, pussy_juice, pink_bow, semi-rimless_eyewear, black-framed_eyewear, under-rim_eyewear, wooden_floor, door, bridal_garter']}
# 耗时1.7691285610198975秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, bangs, blue_eyes, black_hair, hair_ornament, navel, nipples, braid, nude, small_breasts, censored, glasses, pussy, hairclip, indoors, spread_legs, cum, blunt_bangs, mole, mosaic_censoring, twin_braids, loli, completely_nude, cum_in_pussy, squatting, cum_on_body, facial, after_sex, cumdrip, spread_pussy, cum_in_mouth, hair_tie, after_vaginal, cum_on_legs']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, bangs, blue_eyes, black_hair, hair_ornament, navel, nipples, braid, nude, small_breasts, censored, glasses, pussy, hairclip, indoors, spread_legs, cum, blunt_bangs, mole, mosaic_censoring, twin_braids, loli, completely_nude, cum_in_pussy, squatting, cum_on_body, facial, after_sex, cumdrip, spread_pussy, cum_in_mouth, hair_tie, after_vaginal, cum_on_legs']}
# 耗时1.8111515045166016秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, skirt, black_hair, navel, sitting, underwear, panties, braid, pleated_skirt, censored, glasses, pussy, indoors, spread_legs, miniskirt, bra, mosaic_censoring, twin_braids, flat_chest, plaid, loli, window, no_panties, plaid_skirt, pink_bra']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, skirt, black_hair, navel, sitting, underwear, panties, braid, pleated_skirt, censored, glasses, pussy, indoors, spread_legs, miniskirt, bra, mosaic_censoring, twin_braids, flat_chest, plaid, loli, window, no_panties, plaid_skirt, pink_bra']}
# 耗时1.6817700862884521秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, smile, open_mouth, bangs, black_hair, navel, nipples, ponytail, ass, nude, sweat, outdoors, censored, shoes, teeth, pussy, day, socks, spread_legs, black_eyes, mosaic_censoring, flat_chest, loli, anus, squatting, grass, white_socks, sneakers, spread_pussy, ribs, public_nudity']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, smile, open_mouth, bangs, black_hair, navel, nipples, ponytail, ass, nude, sweat, outdoors, censored, shoes, teeth, pussy, day, socks, spread_legs, black_eyes, mosaic_censoring, flat_chest, loli, anus, squatting, grass, white_socks, sneakers, spread_pussy, ribs, public_nudity']}
# 耗时1.771409511566162秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, open_mouth, bangs, black_hair, hair_ornament, navel, nipples, ponytail, ass, nude, sweat, outdoors, censored, barefoot, teeth, pussy, day, spread_legs, black_eyes, mosaic_censoring, flat_chest, feet, tree, fingernails, loli, completely_nude, anus, toes, squatting, scrunchie, hair_scrunchie, toenails, spread_pussy, ribs']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, open_mouth, bangs, black_hair, hair_ornament, navel, nipples, ponytail, ass, nude, sweat, outdoors, censored, barefoot, teeth, pussy, day, spread_legs, black_eyes, mosaic_censoring, flat_chest, feet, tree, fingernails, loli, completely_nude, anus, toes, squatting, scrunchie, hair_scrunchie, toenails, spread_pussy, ribs']}
# 耗时1.7896244525909424秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, black_hair, navel, closed_mouth, nipples, ponytail, nude, sweat, outdoors, censored, pussy, day, spread_legs, cum, black_eyes, mosaic_censoring, flat_chest, loli, completely_nude, cum_in_pussy, squatting, after_sex, cumdrip, spread_pussy, after_vaginal']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, smile, bangs, black_hair, navel, closed_mouth, nipples, ponytail, nude, sweat, outdoors, censored, pussy, day, spread_legs, cum, black_eyes, mosaic_censoring, flat_chest, loli, completely_nude, cum_in_pussy, squatting, after_sex, cumdrip, spread_pussy, after_vaginal']}
# 耗时1.7324485778808594秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, hair_ornament, navel, nipples, ponytail, ass, nude, sweat, small_breasts, outdoors, censored, shoes, teeth, pussy, day, socks, spread_legs, cum, black_footwear, mole, grin, black_eyes, mosaic_censoring, loli, cum_in_pussy, squatting, sneakers, cumdrip, spread_pussy, fence, leaning_back, after_vaginal, public_indecency, ribs, exhibitionism, public_nudity']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, smile, bangs, black_hair, hair_ornament, navel, nipples, ponytail, ass, nude, sweat, small_breasts, outdoors, censored, shoes, teeth, pussy, day, socks, spread_legs, cum, black_footwear, mole, grin, black_eyes, mosaic_censoring, loli, cum_in_pussy, squatting, sneakers, cumdrip, spread_pussy, fence, leaning_back, after_vaginal, public_indecency, ribs, exhibitionism, public_nudity']}
# 耗时1.7665519714355469秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, bangs, black_hair, navel, twintails, brown_eyes, sitting, nipples, collarbone, braid, nude, outdoors, censored, parted_lips, glasses, pussy, day, spread_legs, cum, mosaic_censoring, twin_braids, flat_chest, lips, wet, loli, completely_nude, cum_in_pussy, arm_support, beach, after_sex, cumdrip, leaning_back, after_vaginal, m_legs, blue-framed_eyewear']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, smile, bangs, black_hair, navel, twintails, brown_eyes, sitting, nipples, collarbone, braid, nude, outdoors, censored, parted_lips, glasses, pussy, day, spread_legs, cum, mosaic_censoring, twin_braids, flat_chest, lips, wet, loli, completely_nude, cum_in_pussy, arm_support, beach, after_sex, cumdrip, leaning_back, after_vaginal, m_legs, blue-framed_eyewear']}
# 耗时1.7536447048187256秒
# {'tags': ['1girl, long_hair, breasts, looking_at_viewer, smile, bangs, black_hair, bow, navel, animal_ears, brown_eyes, sitting, braid, short_sleeves, thighs, small_breasts, censored, parted_lips, glasses, pussy, bowtie, rabbit_ears, twin_braids, flat_chest, leotard, see-through, covered_navel, fake_animal_ears, playboy_bunny, black_leotard, see-through_leotard']}
# {'text': ['1girl, long_hair, breasts, looking_at_viewer, smile, bangs, black_hair, bow, navel, animal_ears, brown_eyes, sitting, braid, short_sleeves, thighs, small_breasts, censored, parted_lips, glasses, pussy, bowtie, rabbit_ears, twin_braids, flat_chest, leotard, see-through, covered_navel, fake_animal_ears, playboy_bunny, black_leotard, see-through_leotard']}
# 耗时1.779231071472168秒
# {'tags': ['1girl, long_hair, looking_at_viewer, blush, smile, bangs, black_hair, thighhighs, 1boy, navel, animal_ears, twintails, nipples, braid, hetero, hairband, censored, parted_lips, penis, glasses, pussy, solo_focus, black_thighhighs, indoors, spread_legs, sex, rabbit_ears, mosaic_censoring, vaginal, twin_braids, flat_chest, loli, fake_animal_ears, bottomless, pov, straddling, cowgirl_position, shrug_\\(clothing\\), squatting_cowgirl_position, reverse_outfit, reverse_bunnysuit']}
# {'text': ['1girl, long_hair, looking_at_viewer, blush, smile, bangs, black_hair, thighhighs, 1boy, navel, animal_ears, twintails, nipples, braid, hetero, hairband, censored, parted_lips, penis, glasses, pussy, solo_focus, black_thighhighs, indoors, spread_legs, sex, rabbit_ears, mosaic_censoring, vaginal, twin_braids, flat_chest, loli, fake_animal_ears, bottomless, pov, straddling, cowgirl_position, shrug_\\(clothing\\), squatting_cowgirl_position, reverse_outfit, reverse_bunnysuit']}
# 耗时1.6721367835998535秒
# {'tags': ['1girl, long_hair, breasts, looking_at_viewer, bangs, black_hair, gloves, 1boy, bow, navel, animal_ears, closed_mouth, nipples, closed_eyes, braid, hetero, nude, sweat, small_breasts, censored, parted_lips, penis, glasses, pussy, solo_focus, black_gloves, elbow_gloves, indoors, spread_legs, sex, bowtie, rabbit_ears, mosaic_censoring, vaginal, twin_braids, flat_chest, lips, black_bow, pussy_juice, detached_collar, fake_animal_ears, pov, squatting, straddling, girl_on_top, facing_viewer, cowgirl_position, black_bowtie, squatting_cowgirl_position']}
# {'text': ['1girl, long_hair, breasts, looking_at_viewer, bangs, black_hair, gloves, 1boy, bow, navel, animal_ears, closed_mouth, nipples, closed_eyes, braid, hetero, nude, sweat, small_breasts, censored, parted_lips, penis, glasses, pussy, solo_focus, black_gloves, elbow_gloves, indoors, spread_legs, sex, bowtie, rabbit_ears, mosaic_censoring, vaginal, twin_braids, flat_chest, lips, black_bow, pussy_juice, detached_collar, fake_animal_ears, pov, squatting, straddling, girl_on_top, facing_viewer, cowgirl_position, black_bowtie, squatting_cowgirl_position']}
# 耗时1.7452692985534668秒
# {'tags': ['1girl, solo, long_hair, looking_at_viewer, blush, open_mouth, bangs, black_hair, bare_shoulders, collarbone, braid, sweat, censored, glasses, pussy, black_eyes, twin_braids, flat_chest, bare_arms, loli, pussy_juice, no_panties, bottomless, table, camisole, masturbation, female_masturbation, black_camisole, crotch_rub']}
# {'text': ['1girl, solo, long_hair, looking_at_viewer, blush, open_mouth, bangs, black_hair, bare_shoulders, collarbone, braid, sweat, censored, glasses, pussy, black_eyes, twin_braids, flat_chest, bare_arms, loli, pussy_juice, no_panties, bottomless, table, camisole, masturbation, female_masturbation, black_camisole, crotch_rub']}
# 耗时1.8175251483917236秒
# {'tags': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, open_mouth, bangs, shirt, black_hair, navel, twintails, underwear, nipples, collarbone, white_shirt, braid, small_breasts, censored, glasses, barefoot, pussy, day, indoors, spread_legs, clothes_lift, bra, black_eyes, mosaic_censoring, twin_braids, loli, pussy_juice, anus, bottomless, shirt_lift, squatting, semi-rimless_eyewear, masturbation, fingering, female_masturbation, hair_tie, bra_lift']}
# {'text': ['1girl, solo, long_hair, breasts, looking_at_viewer, blush, open_mouth, bangs, shirt, black_hair, navel, twintails, underwear, nipples, collarbone, white_shirt, braid, small_breasts, censored, glasses, barefoot, pussy, day, indoors, spread_legs, clothes_lift, bra, black_eyes, mosaic_censoring, twin_braids, loli, pussy_juice, anus, bottomless, shirt_lift, squatting, semi-rimless_eyewear, masturbation, fingering, female_masturbation, hair_tie, bra_lift']}
# 耗时1.8616225719451904秒

# %%
import pygame
pygame.init()
my_sound = pygame.mixer.Sound('../../assets/sound/download-complete.wav')
my_sound.play()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
